# %% [markdown]
# <h1>Accompanying Jupyter Notebook for the SWAT4HCLS workshop (Edinburgh, 2019)<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#Initialisation" data-toc-modified-id="Initialisation-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Initialisation</a></span><ul class="toc-item"><li><span><a href="#Python-libraries" data-toc-modified-id="Python-libraries-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Python libraries</a></span></li><li><span><a href="#SPARQL-endpoints" data-toc-modified-id="SPARQL-endpoints-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>SPARQL endpoints</a></span></li><li><span><a href="#Python-functions" data-toc-modified-id="Python-functions-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Python functions</a></span></li></ul></li><li><span><a href="#SPARQL-query-examples" data-toc-modified-id="SPARQL-query-examples-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>SPARQL query examples</a></span><ul class="toc-item"><li><span><a href="#Q1:-Retrieve-all-Rhea-reactions-(approved-or-preliminary)-and-their-chemical-equations" data-toc-modified-id="Q1:-Retrieve-all-Rhea-reactions-(approved-or-preliminary)-and-their-chemical-equations-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Q1: Retrieve all Rhea reactions (approved or preliminary) and their chemical equations</a></span></li><li><span><a href="#Q2:-Retrieve-all-approved-reactions-using-L-glutamate-(CHEBI:29985)-AND-L-glutamine-(CHEBI:58359)-in-opposite-reaction-sides." data-toc-modified-id="Q2:-Retrieve-all-approved-reactions-using-L-glutamate-(CHEBI:29985)-AND-L-glutamine-(CHEBI:58359)-in-opposite-reaction-sides.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Q2: Retrieve all approved reactions using L-glutamate (CHEBI:29985) AND L-glutamine (CHEBI:58359) in opposite reaction sides.</a></span></li><li><span><a href="#Q3:-Select-all-approved-reactions-with-CHEBI:17815-(a-1,2-diacyl-sn-glycerol)-or-one-of-its-descendant." data-toc-modified-id="Q3:-Select-all-approved-reactions-with-CHEBI:17815-(a-1,2-diacyl-sn-glycerol)-or-one-of-its-descendant.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Q3: Select all approved reactions with CHEBI:17815 (a 1,2-diacyl-sn-glycerol) or one of its descendant.</a></span></li><li><span><a href="#Q4:-Retrieve-Rhea-reactions-that-involve-cholesterol-using-its-InChiKey" data-toc-modified-id="Q4:-Retrieve-Rhea-reactions-that-involve-cholesterol-using-its-InChiKey-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Q4: Retrieve Rhea reactions that involve cholesterol using its InChiKey</a></span></li><li><span><a href="#Q5:-Distribution-of-Rhea-reactions-based-on-the-first-level-of-IUBMB-enzyme-classification" data-toc-modified-id="Q5:-Distribution-of-Rhea-reactions-based-on-the-first-level-of-IUBMB-enzyme-classification-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Q5: Distribution of Rhea reactions based on the first level of IUBMB enzyme classification</a></span></li><li><span><a href="#Q6:-Retrieve-human-enzyme-metabolizing-cholesterol-and-their-catalized-reactions" data-toc-modified-id="Q6:-Retrieve-human-enzyme-metabolizing-cholesterol-and-their-catalized-reactions-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Q6: Retrieve human enzyme metabolizing cholesterol and their catalized reactions</a></span></li><li><span><a href="#Q7:-Ask-if-there-are-fungal-UniProtKB/Swiss-Prot-protein(s)-metabolizing-cholesterol-(for-QC)" data-toc-modified-id="Q7:-Ask-if-there-are-fungal-UniProtKB/Swiss-Prot-protein(s)-metabolizing-cholesterol-(for-QC)-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Q7: Ask if there are fungal UniProtKB/Swiss-Prot protein(s) metabolizing cholesterol (for QC)</a></span></li><li><span><a href="#Q8:-Where-are-the-human-enzymes-metabolizing-cholesterol-located-in-the-cell?" data-toc-modified-id="Q8:-Where-are-the-human-enzymes-metabolizing-cholesterol-located-in-the-cell?-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Q8: Where are the human enzymes metabolizing cholesterol located in the cell?</a></span></li><li><span><a href="#Q9:-Where-are-the-human-genes-encoding-enzymes-metabolizing-cholesterol-expressed?" data-toc-modified-id="Q9:-Where-are-the-human-genes-encoding-enzymes-metabolizing-cholesterol-expressed?-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Q9: Where are the human genes encoding enzymes metabolizing cholesterol expressed?</a></span></li><li><span><a href="#Q10:-Build-the-UniProt-H.-pylori-proteome-scale-metabolic-network" data-toc-modified-id="Q10:-Build-the-UniProt-H.-pylori-proteome-scale-metabolic-network-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>Q10: Build the UniProt H. pylori proteome scale metabolic network</a></span></li><li><span><a href="#Q11:-Explore-H.-pylori-tryptophan-biosynthesis-pathway-(GO:0000162)" data-toc-modified-id="Q11:-Explore-H.-pylori-tryptophan-biosynthesis-pathway-(GO:0000162)-3.11"><span class="toc-item-num">3.11&nbsp;&nbsp;</span>Q11: Explore H. pylori tryptophan biosynthesis pathway (GO:0000162)</a></span></li><li><span><a href="#Q12:-H.-pylori-enzyme-complexes-for-tryptophan-biosynthesis-pathway-(MetaNetX:-seed_Opt85962_1)" data-toc-modified-id="Q12:-H.-pylori-enzyme-complexes-for-tryptophan-biosynthesis-pathway-(MetaNetX:-seed_Opt85962_1)-3.12"><span class="toc-item-num">3.12&nbsp;&nbsp;</span>Q12: H. pylori enzyme complexes for tryptophan biosynthesis pathway (MetaNetX: seed_Opt85962_1)</a></span></li></ul></li><li><span><a href="#Visualization" data-toc-modified-id="Visualization-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Visualization</a></span><ul class="toc-item"><li><span><a href="#Venn-diagram-showing-the-taxonomic-distribution-of-Rhea-reactions-annotated-in-UniProtKB/Swiss-Prot-(UniProtKB/Swiss-Prot)" data-toc-modified-id="Venn-diagram-showing-the-taxonomic-distribution-of-Rhea-reactions-annotated-in-UniProtKB/Swiss-Prot-(UniProtKB/Swiss-Prot)-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Venn diagram showing the taxonomic distribution of Rhea reactions annotated in UniProtKB/Swiss-Prot (UniProtKB/Swiss-Prot)</a></span><ul class="toc-item"><li><span><a href="#Q20:-Retrieve-UniProtKB/Swiss-Prot-proteins,-their-taxonomic-domain-and-their-catalyzed-Rhea-reactions" data-toc-modified-id="Q20:-Retrieve-UniProtKB/Swiss-Prot-proteins,-their-taxonomic-domain-and-their-catalyzed-Rhea-reactions-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Q20: Retrieve UniProtKB/Swiss-Prot proteins, their taxonomic domain and their catalyzed Rhea reactions</a></span></li><li><span><a href="#Compute-Venn-diagram-using-matplotlib-and-matplotlib_venn-python-libraries" data-toc-modified-id="Compute-Venn-diagram-using-matplotlib-and-matplotlib_venn-python-libraries-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Compute Venn diagram using matplotlib and matplotlib_venn python libraries</a></span></li></ul></li></ul></li><li><span><a href="#IDSM/Sachem-service" data-toc-modified-id="IDSM/Sachem-service-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>IDSM/Sachem service</a></span><ul class="toc-item"><li><span><a href="#Q30:-Retrieve-the-Rhea-reactions-that-involve-cholesterol-or-cholesterol-derivatives" data-toc-modified-id="Q30:-Retrieve-the-Rhea-reactions-that-involve-cholesterol-or-cholesterol-derivatives-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Q30: Retrieve the Rhea reactions that involve cholesterol or cholesterol derivatives</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Introduction
#
# This notebook is an hands-on introduction to querying metabolism related data across multiple data sources using SPARQL.
#
# |Source | Description | web site | SPARQL endpoint |
# |-------|-------------|----------|-----------------|
# | Rhea | chemical reactions | https://www.rhea-db.org/ | https://sparql.uniprot.org/sparql/ |
# | UniProt | protein sequences and annotations | https://www.uniprot.org/ |https://sparql.rhea-db.org/sparql |
# | Bgee | expression data |https://bgee.org/ | hosted by http://biosoda.expasy.org/ |
# | MetaNetX | reconciled metabolic networks | https://www.metanetx.org/ | https://rdf.metanetx.org/|
# | bioSODA | Bio-Query: Federated template search over biological databases | |http://biosoda.expasy.org/|
#
# This notebook is built with a **Python3 kernel** and uses the **SPARQLWrapper** and **pandas** python libraries.
#
# **Note that you can simply use this notebook as a list of SPARQL queries that you can execute somewhere else.**
# Each query starts with a comment line (#) indicating the SPARQL endpoint to be used to run the query.
#
# Example: Q1 query
# \#endpoint: https://sparql.rhea-db.org/sparql
# Go to https://sparql.rhea-db.org/sparql and copy/paste Q1 query in the query form.

# %% [markdown]
# # Initialisation
# This notebook uses a Python3 kernel.

# %% [markdown]
# ## Python libraries
#
# **Dependencies:**
# - **SPARQLWrapper**
# SPARQLWrapper is a wrapper around a SPARQL service. It helps in creating the query URI and, possibly, convert the result into a more manageable format. The package is licensed under W3C license.
# useful links: https://rdflib.github.io/sparqlwrapper/ and https://pypi.org/project/SPARQLWrapper/
# - **pandas**
# pandas is a Python package providing fast, flexible, and expressive data structures designed to make working with structured (tabular, multidimensional, potentially heterogeneous) and time series data both easy and intuitive.
# useful link: https://pypi.org/project/pandas/

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
from pandas.io.json import json_normalize

# %% [markdown]
# ## SPARQL endpoints

# %%
sparql_uniprot_url = "https://sparql.uniprot.org/sparql/"
sparql_rhea_url = "https://sparql.rhea-db.org/sparql"

# %% [markdown]
# ## Python functions

# %%
def sparql2pandas(sparql_query, sparql_service_url):
    """
    Use SPARQLWrapper to query a SPARQL endpoint (sparql_service_url) with a given SPARQL query string 
    (sparql_query) that uses SELECT query form.
    Return the SPARQL query result as a pandas Dataframe.
    """
    #
    # run the SPARQL query
    #
    sparql=SPARQLWrapper(sparql_service_url)    
    sparql.setQuery(sparql_query)
    sparql.setReturnFormat(JSON)    
    res = sparql.query().convert()
    
    # convert the JSON result (res) in a pandas dataframe
    res_sparql_df = json_normalize(res["results"]["bindings"])
    
    # distinguish .type and .value
    col_type = [c for c in res_sparql_df.columns.tolist() if ".type" in c]
    col_value = [c for c in res_sparql_df.columns.tolist() if ".value" in c]
    col_datatype = [c for c in res_sparql_df.columns.tolist() if ".datatype" in c]
    
    # Remove .type columns
    res_sparql_df.drop(col_type,axis=1,inplace=True)
    # Remove .datatype columns
    res_sparql_df.drop(col_datatype,axis=1,inplace=True)    
    # Remove ".value" from column names
    res_sparql_df = res_sparql_df.rename(columns = lambda col: col.replace(".value", ""))
    
    return res_sparql_df

# %% [markdown]
# # SPARQL query examples

# %% [markdown]
# ## Q1: Retrieve all Rhea reactions (approved or preliminary) and their chemical equations

# %%
sparql_Q1="""
#endpoint: https://sparql.rhea-db.org/sparql
#query Q1: retrieve all Rhea reactions (approved or preliminary) and their chemical equations.

PREFIX rh:<http://rdf.rhea-db.org/>

SELECT ?reaction ?reactionEquation 
WHERE {
  # ?reaction rdfs:subClassOf rh:Reaction .
  # ?reaction rh:status ?status .
  VALUES ?status {rh:Approved rh:Preliminary}
  # ?reaction rh:equation ?reactionEquation .
}
ORDER BY ?reaction
"""
print(sparql_Q1)
# Out:
# #endpoint: https://sparql.rhea-db.org/sparql
# #query Q1: retrieve all Rhea reactions (approved or preliminary) and their chemical equations.
#
# PREFIX rh:<http://rdf.rhea-db.org/>
#
# SELECT ?reaction ?reactionEquation
# WHERE {
#   ?reaction rdfs:subClassOf rh:Reaction .
#   ?reaction rh:status ?status .
#   VALUES ?status {rh:Approved rh:Preliminary}
#   ?reaction rh:equation ?reactionEquation .
# }
# ORDER BY ?reaction

# %%
# Execute sparql_Q1
try:
    df  = sparql2pandas(sparql_Q1,sparql_rhea_url)
except Exception:
    print('ERROR in SPARQL query Q1')

# Display the 5 first rows
df.head(5)
# Out:
#                        reaction  \
# 0  http://rdf.rhea-db.org/10000
# 1  http://rdf.rhea-db.org/10004
# 2  http://rdf.rhea-db.org/10008
# 3  http://rdf.rhea-db.org/10012
# 4  http://rdf.rhea-db.org/10016
#
#                                     reactionEquation
# 0            H2O + pentanamide = NH4(+) + pentanoate
# 1         benzyl isothiocyanate = benzyl thiocyanate
# 2  [protein]-dithiol + a hydroperoxide = [protein...
# 3  (R)-6-hydroxynicotine + H2O + O2 = 6-hydroxyps...
# 4  H2O + O-sinapoylcholine = choline + H(+) + tra...

# %% [markdown]
# ## Q2: Retrieve all approved reactions using L-glutamate (CHEBI:29985) AND L-glutamine (CHEBI:58359) in opposite reaction sides.

# %%
chebi1 = 'CHEBI_29985'
chebi2 = 'CHEBI_58359'

sparql_Q2="""
#endpoint:https://sparql.rhea-db.org/sparql
#query Q2: Q2: Retrieve all approved reactions using 
#          L-glutamate (CHEBI:29985) AND L-glutamine (CHEBI:58359) 
#          in opposite reaction sides.  

PREFIX rh:<http://rdf.rhea-db.org/>
PREFIX ch:<http://purl.obolibrary.org/obo/>

SELECT ?reaction WHERE {
  # ?reaction rdfs:subClassOf rh:Reaction .
  # ?reaction rh:status rh:Approved .

  # ?reaction rh:side ?reactionSide1 .
  # ?reactionSide1 rh:contains ?participant1 .
  # ?participant1 rh:compound ?compound1 .
  # ?compound1 rh:chebi ch:""" + chebi1 + """ .

  # ?reaction rh:side ?reactionSide2 .
  # ?reactionSide2 rh:contains ?participant2 .
  # ?participant2 rh:compound ?compound2 .
  # ?compound2 rh:chebi ch:""" + chebi2 + """ .

  # ?reactionSide1 rh:transformableTo ?reactionSide2 .
}"""

print(sparql_Q2)
# Out:
# #endpoint:https://sparql.rhea-db.org/sparql
# #query Q2: Q2: Retrieve all approved reactions using
# #          L-glutamate (CHEBI:29985) AND L-glutamine (CHEBI:58359)
# #          in opposite reaction sides.
#
# PREFIX rh:<http://rdf.rhea-db.org/>
# PREFIX ch:<http://purl.obolibrary.org/obo/>
#
# SELECT ?reaction
# WHERE {
#   ?reaction rdfs:subClassOf rh:Reaction .
#   ?reaction rh:status rh:Approved .
#
#   ?reaction rh:side ?reactionSide1 .
#   ?reactionSide1 rh:contains ?participant1 .
#   ?participant1 rh:compound ?compound1 .
#   ?compound1 rh:chebi ch:CHEBI_29985 .
#
#   ?reaction rh:side ?reactionSide2 .
#   ?reactionSide2 rh:contains ?participant2 .
#   ?participant2 rh:compound ?compound2 .
#   ?compound2 rh:chebi ch:CHEBI_58359 .
#
#   ?reactionSide1 rh:transformableTo ?reactionSide2 .
# }

# %%
try:
    df  = sparql2pandas(sparql_Q2,sparql_rhea_url)
except Exception:
    print('ERROR in SPARQL query Q2')
    stop

# Display the 5 first rows
df.head(5)
# Out:
#                        reaction
# 0  http://rdf.rhea-db.org/21732
# 1  http://rdf.rhea-db.org/23256
# 2  http://rdf.rhea-db.org/24384
# 3  http://rdf.rhea-db.org/24793
# 4  http://rdf.rhea-db.org/25512

# %% [markdown]
# ## Q3: Select all approved reactions with CHEBI:17815 (a 1,2-diacyl-sn-glycerol) or one of its descendant.

# %%
chebi = 'CHEBI_17815'
sparql_Q3="""
#endpoint:https://sparql.rhea-db.org/sparql
#query Q3: Select all approved reactions with CHEBI:17815 (a 1,2-diacyl-sn-glycerol) or one of its descendant

PREFIX rh:<http://rdf.rhea-db.org/>
PREFIX ch:<http://purl.obolibrary.org/obo/>
PREFIX up:<http://purl.uniprot.org/core/>

SELECT distinct ?chebi ?chebiUniprotName ?reaction ?reactionEquation 
WHERE {
  # ?reaction rdfs:subClassOf rh:Reaction .
  # ?reaction rh:status rh:Approved .
  # ?reaction rh:equation ?reactionEquation .
  # ?reaction rh:side ?reactionSide .
  # ?reactionSide rh:contains ?participant .
  # ?participant rh:compound ?compound .
  # ?compound rh:chebi ?chebi .
  # ?chebi rdfs:subClassOf* ch:""" + chebi + """ .
  # ?chebi up:name ?chebiUniprotName .
}
ORDER BY ?chebi
"""
print(sparql_Q3)
# Out:
# #endpoint:https://sparql.rhea-db.org/sparql
# #query Q3: Select all approved reactions with CHEBI:17815 (a 1,2-diacyl-sn-glycerol) or one of its descendant
#
# PREFIX rh:<http://rdf.rhea-db.org/>
# PREFIX ch:<http://purl.obolibrary.org/obo/>
# PREFIX up:<http://purl.uniprot.org/core/>
#
# SELECT distinct ?chebi ?chebiUniprotName ?reaction ?reactionEquation
# WHERE {
#   ?reaction rdfs:subClassOf rh:Reaction .
#   ?reaction rh:status rh:Approved .
#   ?reaction rh:equation ?reactionEquation .
#   ?reaction rh:side ?reactionSide .
#   ?reactionSide rh:contains ?participant .
#   ?participant rh:compound ?compound .
#   ?compound rh:chebi ?chebi .
#   ?chebi rdfs:subClassOf* ch:CHEBI_17815 .
#   ?chebi up:name ?chebiUniprotName .
# }
# ORDER BY ?chebi

# %%
try:
    df  = sparql2pandas(sparql_Q3,sparql_rhea_url)
except Exception:
    print('ERROR in SPARQL query Q3')
    stop
    
# Display the 5 first rows
df.head(5)
# Out:
#                                          chebi  \
# 0  http://purl.obolibrary.org/obo/CHEBI_140452
# 1  http://purl.obolibrary.org/obo/CHEBI_140526
# 2   http://purl.obolibrary.org/obo/CHEBI_17815
# 3   http://purl.obolibrary.org/obo/CHEBI_17815
# 4   http://purl.obolibrary.org/obo/CHEBI_17815
#
#                                     chebiUniprotName  \
# 0  1-O-(1Z-octadecenoyl)-2-(9Z-octadecenoyl)-sn-g...
# 1                         1,2-dihexanoyl-sn-glycerol
# 2                           a 1,2-diacyl-sn-glycerol
# 3                           a 1,2-diacyl-sn-glycerol
# 4                           a 1,2-diacyl-sn-glycerol
#
#                        reaction  \
# 0  http://rdf.rhea-db.org/56464
# 1  http://rdf.rhea-db.org/56540
# 2  http://rdf.rhea-db.org/55608
# 3  http://rdf.rhea-db.org/24698
# 4  http://rdf.rhea-db.org/25948
#
#                                     reactionEquation
# 0  1-O-(1Z-octadecenoyl)-2-(9Z-octadecenoyl)-sn-g...
# ...

# %% [markdown]
# ## Q4: Retrieve Rhea reactions that involve cholesterol using its InChiKey

# %%
inchikey = 'HVYWMOMLDIMFJA-DPAQBDIFSA-N'
sparql_Q4="""
#endpoint:https://sparql.rhea-db.org/sparql
#query Q4: Retrieve Rhea reactions that involve cholesterol using its InChiKey

PREFIX rh:<http://rdf.rhea-db.org/>
PREFIX ch:<http://purl.obolibrary.org/obo/>
PREFIX ch3:<http://purl.obolibrary.org/obo/chebi/> 
PREFIX up:<http://purl.uniprot.org/core/>

SELECT distinct ?chebi 
                # ?chebiUniprotName 
                # ?reaction 
                # ?reactionEquation 
WHERE {
  # ?reaction rdfs:subClassOf rh:Reaction .
  # ?reaction rh:status ?status .
  VALUES (?status) {(rh:Approved) (rh:Preliminary)}
  # ?reaction rh:equation ?reactionEquation .
  # ?reaction rh:side ?reactionSide .
  # ?reactionSide rh:contains ?participant .
  # ?participant rh:compound ?compound .
  # ?compound rh:chebi ?chebi .
  # ?chebi up:name ?chebiUniprotName .
  # ?chebi ch3:inchikey ?inchikey .
  VALUES (?inchikey) {('""" + inchikey + """')}
}
ORDER BY ?reaction
"""

print(sparql_Q4)
# Out:
# #endpoint:https://sparql.rhea-db.org/sparql
# #query Q4: Retrieve Rhea reactions that involve cholesterol using its InChiKey
#
# PREFIX rh:<http://rdf.rhea-db.org/>
# PREFIX ch:<http://purl.obolibrary.org/obo/>
# PREFIX ch3:<http://purl.obolibrary.org/obo/chebi/>
# PREFIX up:<http://purl.uniprot.org/core/>
#
# SELECT distinct ?chebi
#                 ?chebiUniprotName
#                 ?reaction
#                 ?reactionEquation
# WHERE {
#   ?reaction rdfs:subClassOf rh:Reaction .
#   ?reaction rh:status ?status .
#   VALUES (?status) {(rh:Approved) (rh:Preliminary)}
#   ?reaction rh:equation ?reactionEquation .
#   ?reaction rh:side ?reactionSide .
#   ?reactionSide rh:contains ?participant .
#   ?participant rh:compound ?compound .
#   ?compound rh:chebi ?chebi .
#   ?chebi up:name ?chebiUniprotName .
#   ?chebi ch3:inchikey ?inchikey .
#   VALUES (?inchikey) {('HVYWMOMLDIMFJA-DPAQBDIFSA-N')}
# }
# ORDER BY ?reaction

# %%
try:
    df  = sparql2pandas(sparql_Q4,sparql_rhea_url)
except Exception:
    print('ERROR in SPARQL query Q4')
    stop
    
# Display the 5 first rows
df.head(5)
# Out:
#                                         chebi chebiUniprotName  \
# 0  http://purl.obolibrary.org/obo/CHEBI_16113      cholesterol
# 1  http://purl.obolibrary.org/obo/CHEBI_16113      cholesterol
# 2  http://purl.obolibrary.org/obo/CHEBI_16113      cholesterol
# 3  http://purl.obolibrary.org/obo/CHEBI_16113      cholesterol
# 4  http://purl.obolibrary.org/obo/CHEBI_16113      cholesterol
#
#                        reaction  \
# 0  http://rdf.rhea-db.org/11956
# 1  http://rdf.rhea-db.org/17729
# 2  http://rdf.rhea-db.org/21104
# 3  http://rdf.rhea-db.org/21328
# 4  http://rdf.rhea-db.org/21812
#
#                                     reactionEquation
# 0  cholesteryl-beta-D-glucoside + H2O = cholester...
# 1  an acyl-CoA + cholesterol = a cholesterol este...
# 2  AH2 + cholesterol + O2 = 25-hydroxycholesterol...
# 3       cholesterol + O2 = cholest-4-en-3-one + H2O2
# 4  cholesterol + O2 + reduced [NADPH--hemoprotein...

# %% [markdown]
# ## Q5: Distribution of Rhea reactions based on the first level of IUBMB enzyme classification

# %%
sparql_Q5="""
#endpoint:https://sparql.rhea-db.org/sparql

PREFIX rh:<http://rdf.rhea-db.org/>
PREFIX ec:<http://purl.uniprot.org/enzyme/>
PREFIX rdfs:<http://www.w3.org/2000/01/rdf-schema#>
PREFIX skos:<http://www.w3.org/2004/02/skos/core#> 

SELECT ?ecClass 
       # ?ecClassName
       (count(?reaction) as ?reactionCount)
WHERE
{
  SERVICE <http://sparql.uniprot.org/sparql> {
    # ?ec rdfs:subClassOf ?ecClass .
    # ?ecClass skos:prefLabel ?ecClassName .
    VALUES (?ecClass) { (ec:1.-.-.-) (ec:2.-.-.-)(ec:3.-.-.-)
                        (ec:4.-.-.-)(ec:5.-.-.-) (ec:6.-.-.-) 
                        (ec:7.-.-.-) }
  }
  # ?reaction rh:ec ?ec .
}
ORDER BY ?ecClass
"""
print(sparql_Q5)
# Out:
# #endpoint:https://sparql.rhea-db.org/sparql
#
# PREFIX rh:<http://rdf.rhea-db.org/>
# PREFIX ec:<http://purl.uniprot.org/enzyme/>
# PREFIX rdfs:<http://www.w3.org/2000/01/rdf-schema#>
# PREFIX skos:<http://www.w3.org/2004/02/skos/core#>
#
# SELECT ?ecClass
#        ?ecClassName
#        (count(?reaction) as ?reactionCount)
# WHERE
# {
#   SERVICE <http://sparql.uniprot.org/sparql> {
#     ?ec rdfs:subClassOf ?ecClass .
#     ?ecClass skos:prefLabel ?ecClassName .
#     VALUES (?ecClass) { (ec:1.-.-.-) (ec:2.-.-.-)(ec:3.-.-.-)
#                         (ec:4.-.-.-)(ec:5.-.-.-) (ec:6.-.-.-)
#                         (ec:7.-.-.-) }
#   }
#   ?reaction rh:ec ?ec .
# }
# ORDER BY ?ecClass

# %%
try:
    df  = sparql2pandas(sparql_Q5,sparql_rhea_url)
except Exception:
    print('ERROR in SPARQL query Q5')
    stop
    
# Display all result (7 IUBMB enzyme classes)
df
# Out:
#                                   ecClass      ecClassName reactionCount
# 0  http://purl.uniprot.org/enzyme/1.-.-.-  Oxidoreductases          2445
# 1  http://purl.uniprot.org/enzyme/2.-.-.-     Transferases          2218
# 2  http://purl.uniprot.org/enzyme/3.-.-.-       Hydrolases           909
# 3  http://purl.uniprot.org/enzyme/4.-.-.-           Lyases           760
# 4  http://purl.uniprot.org/enzyme/5.-.-.-       Isomerases           322
# 5  http://purl.uniprot.org/enzyme/6.-.-.-          Ligases           224
# 6  http://purl.uniprot.org/enzyme/7.-.-.-     Translocases            76

# %% [markdown]
# ## Q6: Retrieve human enzyme metabolizing cholesterol and their catalized reactions

# %%
# Homo sapiens (human), species
taxid = '9606'
# cholesterol
chebi = 'CHEBI_16113'

sparql_Q6="""
#endpoint:https://sparql.rhea-db.org/sparql

PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX up: <http://purl.uniprot.org/core/>
PREFIX taxon:<http://purl.uniprot.org/taxonomy/> 
PREFIX rh: <http://rdf.rhea-db.org/>
PREFIX ch:<http://purl.obolibrary.org/obo/>

SELECT DISTINCT ?protein  
                # ?proteinId
                # ?proteinName
                # ?reaction 
                # ?reactionEquation 
WHERE {
  # ?reaction rdfs:subClassOf rh:Reaction .
  # ?reaction rh:side ?reactionSide .
  # ?reactionSide rh:contains ?participant .
  # ?participant rh:compound ?compound .
  # ?compound rh:chebi ch:""" + chebi + """ .
  # ?reaction rh:equation ?reactionEquation .
  
  SERVICE <https://sparql.uniprot.org/sparql/> {
    # ?protein up:mnemonic ?proteinId .
    # ?protein up:recommendedName ?rn .
    # ?rn up:fullName ?proteinName .
    # ?protein up:organism taxon:""" + taxid + """ .
    # ?protein up:annotation ?a1 .
    # ?a1 a up:Catalytic_Activity_Annotation .
    # ?a1 up:catalyticActivity ?ca .
    # ?ca up:catalyzedReaction ?reaction .  
  }
}
ORDER BY ?proteinName
"""

print(sparql_Q6)
# Out:
# #endpoint:https://sparql.rhea-db.org/sparql
#
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX up: <http://purl.uniprot.org/core/>
# PREFIX taxon:<http://purl.uniprot.org/taxonomy/>
# PREFIX rh: <http://rdf.rhea-db.org/>
# PREFIX ch:<http://purl.obolibrary.org/obo/>
#
# SELECT DISTINCT ?protein
#                 ?proteinId
#                 ?proteinName
#                 ?reaction
#                 ?reactionEquation
# WHERE {
#   ?reaction rdfs:subClassOf rh:Reaction .
#   ?reaction rh:side ?reactionSide .
#   ?reactionSide rh:contains ?participant .
#   ?participant rh:compound ?compound .
#   ?compound rh:chebi ch:CHEBI_16113 .
#   ?reaction rh:equation ?reactionEquation .
#
#   SERVICE <https://sparql.uniprot.org/sparql/> {
#     ?protein up:mnemonic ?proteinId .
#     ?protein up:recommendedName ?rn .
#     ?rn up:fullName ?proteinName .
#     ?protein up:organism taxon:9606 .
#     ?protein up:annotation ?a1 .
#     ?a1 a up:Catalytic_Activity_Annotation .
# ...

# %%
try:
    df  = sparql2pandas(sparql_Q6,sparql_rhea_url)
except Exception:
    print('ERROR in SPARQL query Q6')
    stop
    
# Display the 5 first rows
df.head(5)
# Out:
#                                   protein    proteinId  \
# 0  http://purl.uniprot.org/uniprot/Q9UBM7  DHCR7_HUMAN
# 1  http://purl.uniprot.org/uniprot/P45844  ABCG1_HUMAN
# 2  http://purl.uniprot.org/uniprot/Q9H221  ABCG8_HUMAN
# 3  http://purl.uniprot.org/uniprot/Q9H222  ABCG5_HUMAN
# 4  http://purl.uniprot.org/uniprot/P19835    CEL_HUMAN
#
#                                   proteinName                      reaction  \
# 0              7-dehydrocholesterol reductase  http://rdf.rhea-db.org/23984
# 1  ATP-binding cassette sub-family G member 1  http://rdf.rhea-db.org/39051
# 2  ATP-binding cassette sub-family G member 8  http://rdf.rhea-db.org/39051
# 3  ATP-binding cassette sub-family G member 5  http://rdf.rhea-db.org/39051
# 4                  Bile salt-activated lipase  http://rdf.rhea-db.org/33875
#
#                                     reactionEquation
# 0  cholesterol + NADP(+) = cholesta-5,7-dien-3bet...
# 1  ATP + cholesterol(in) + H2O = ADP + cholestero...
# ...

# %% [markdown]
# ## Q7: Ask if there are fungal UniProtKB/Swiss-Prot protein(s) metabolizing cholesterol (for QC)
#
# **ASK** query form returns a boolean indicating whether a query pattern matches or not.
#
# Expected answer: _False_
# Answer (UniProt release 2019_10): _True_
#
# QC: The error was reported to UniProt curators and will be fixed in the 2020_01 release.

# %%
# Fungi (fungi), kingdom
taxid = '4751'
# cholesterol
chebi = 'CHEBI_16113'

sparql_Q7="""
#endpoint: https://sparql.uniprot.org/sparql/
#query Q7: Ask if there are fungal UniProtKB/Swiss-Prot protein(s) metabolizing cholesterol.

PREFIX up:<http://purl.uniprot.org/core/>
PREFIX rh:<http://rdf.rhea-db.org/>
PREFIX taxon:<http://purl.uniprot.org/taxonomy/>
PREFIX ch:<http://purl.obolibrary.org/obo/>
ASK {
  SERVICE <https://sparql.rhea-db.org/sparql> {
    # ?reaction rdfs:subClassOf rh:Reaction .
    # ?reaction rh:status ?status .
    VALUES (?status) {(rh:Approved) (rh:Preliminary)}
    # ?reaction rh:side ?reactionSide .
    # ?reactionSide rh:contains ?participant .
    # ?participant rh:compound ?compound .
    # ?compound rh:chebi ch:""" + chebi + """ .
  }
  # ?protein up:annotation/up:catalyticActivity/up:catalyzedReaction ?reaction .
  # ?protein up:organism/rdfs:subClassOf taxon:""" + taxid + """ .

}"""

print(sparql_Q7)
# Out:
# #endpoint: https://sparql.uniprot.org/sparql/
# #query Q7: Ask if there are fungal UniProtKB/Swiss-Prot protein(s) metabolizing cholesterol.
#
# PREFIX up:<http://purl.uniprot.org/core/>
# PREFIX rh:<http://rdf.rhea-db.org/>
# PREFIX taxon:<http://purl.uniprot.org/taxonomy/>
# PREFIX ch:<http://purl.obolibrary.org/obo/>
# ASK {
#   SERVICE <https://sparql.rhea-db.org/sparql> {
#     ?reaction rdfs:subClassOf rh:Reaction .
#     ?reaction rh:status ?status .
#     VALUES (?status) {(rh:Approved) (rh:Preliminary)}
#     ?reaction rh:side ?reactionSide .
#     ?reactionSide rh:contains ?participant .
#     ?participant rh:compound ?compound .
#     ?compound rh:chebi ch:CHEBI_16113 .
#   }
#   ?protein up:annotation/up:catalyticActivity/up:catalyzedReaction ?reaction .
#   ?protein up:organism/rdfs:subClassOf taxon:4751 .
#
# }

# %%
# The result of a SPARQL query using ASK as query form is a boolean.
# No need to convert it in a pandas dataframe!

sparqlUniprot = SPARQLWrapper(sparql_uniprot_url)
sparqlUniprot.setQuery(sparql_Q7)
sparqlUniprot.setReturnFormat(JSON)
results = sparqlUniprot.query().convert()

if results['boolean']:
    print('Unexpected result:',results['boolean'])
else:
    print('Expected result:',results['boolean'])
# Out:
# Unexpected result: True

# %% [markdown]
# ## Q8: Where are the human enzymes metabolizing cholesterol located in the cell?
#
# Retrieve the UniProt proteins, their catalyzed reactions and their subcellular location(s) (UniProt locations and GO Cellular Component ID)

# %%
# Homo sapiens (human), species
taxid = '9606'
# cholesterol
chebi = 'CHEBI_16113'

sparql_Q8="""
#endpoint: https://sparql.uniprot.org/sparql/
#query Q8: Where are the human enzymes metabolizing cholesterol located in the cell?

PREFIX rdfs:<http://www.w3.org/2000/01/rdf-schema#> 
PREFIX rh:<http://rdf.rhea-db.org/>
PREFIX ch:<http://purl.obolibrary.org/obo/> 
PREFIX up:<http://purl.uniprot.org/core/>
PREFIX taxon:<http://purl.uniprot.org/taxonomy/>
PREFIX skos:<http://www.w3.org/2004/02/skos/core#>

SELECT distinct ?protein
                # ?reaction 
                # ?upLocation 
                # ?upLocationLabel 
                # ?goId
WHERE {
  SERVICE <https://sparql.rhea-db.org/sparql> {
    # ?reaction rdfs:subClassOf rh:Reaction .
    # ?reaction rh:status rh:Approved .
    # ?reaction rh:equation ?reactionEquation .
    # ?reaction rh:side ?reactionSide .
    # ?reactionSide rh:contains ?participant .
    # ?participant rh:compound ?compound .
    # compound constraint
    # ?compound rh:chebi ch:""" + chebi + """ .
  }
  # taxonomy constraint
  # ?protein up:organism taxon:""" + taxid + """ .
  # Rhea catalayzed reactions
  # ?protein up:annotation ?a1 .
  # ?a1 a up:Catalytic_Activity_Annotation .
  # ?a1 up:catalyticActivity ?ca .
  # ?ca up:catalyzedReaction ?reaction .
  # UniProt cellular components
  # ?protein up:annotation ?a2 .    
  # ?a2  a  up:Subcellular_Location_Annotation .    
  # ?a2 up:locatedIn ?lIn .
  # ?lIn up:cellularComponent ?upLocation .    
  # ?upLocation skos:prefLabel ?upLocationLabel  .    
  # ?upLocation skos:exactMatch ?goId .
}
"""
print(sparql_Q8)
# Out:
# #endpoint: https://sparql.uniprot.org/sparql/
# #query Q8: Where are the human enzymes metabolizing cholesterol located in the cell?
#
# PREFIX rdfs:<http://www.w3.org/2000/01/rdf-schema#>
# PREFIX rh:<http://rdf.rhea-db.org/>
# PREFIX ch:<http://purl.obolibrary.org/obo/>
# PREFIX up:<http://purl.uniprot.org/core/>
# PREFIX taxon:<http://purl.uniprot.org/taxonomy/>
# PREFIX skos:<http://www.w3.org/2004/02/skos/core#>
#
# SELECT distinct ?protein
#                 ?reaction
#                 ?upLocation
#                 ?upLocationLabel
#                 ?goId
# WHERE {
#   SERVICE <https://sparql.rhea-db.org/sparql> {
#     ?reaction rdfs:subClassOf rh:Reaction .
#     ?reaction rh:status rh:Approved .
#     ?reaction rh:equation ?reactionEquation .
#     ?reaction rh:side ?reactionSide .
#     ?reactionSide rh:contains ?participant .
#     ?participant rh:compound ?compound .
#     # compound constraint
#     ?compound rh:chebi ch:CHEBI_16113 .
#   }
#   # taxonomy constraint
# ...

# %%
try:
    df  = sparql2pandas(sparql_Q8,sparql_uniprot_url)
except Exception:
    print('ERROR in SPARQL query Q8')
    stop
    
# Display the 5 first rows
df.head(5)
# Out:
#                                         goId  \
# 0  http://purl.obolibrary.org/obo/GO_0005768
# 1  http://purl.obolibrary.org/obo/GO_0000139
# 2  http://purl.obolibrary.org/obo/GO_0000139
# 3  http://purl.obolibrary.org/obo/GO_0000139
# 4  http://purl.obolibrary.org/obo/GO_0000139
#
#                                   protein                      reaction  \
# 0  http://purl.uniprot.org/uniprot/O95477  http://rdf.rhea-db.org/39051
# 1  http://purl.uniprot.org/uniprot/P45844  http://rdf.rhea-db.org/39051
# 2  http://purl.uniprot.org/uniprot/Q15392  http://rdf.rhea-db.org/36391
# 3  http://purl.uniprot.org/uniprot/Q9HCG7  http://rdf.rhea-db.org/11956
# 4  http://purl.uniprot.org/uniprot/Q9HCG7  http://rdf.rhea-db.org/58264
#
#                               upLocation           upLocationLabel
# 0  http://purl.uniprot.org/locations/101                  Endosome
# 1  http://purl.uniprot.org/locations/134  Golgi apparatus membrane
# ...

# %% [markdown]
# ## Q9: Where are the human genes encoding enzymes metabolizing cholesterol expressed?
#
# Retrieve the UniProt proteins, their catalyzed reactions, their encoding genes (Ensembl) and the anatomic entities where the genes are expressed (UBERON anatomic entites from Bgee expression data resource)
#
# **WARNING**: this query may take a few minutes...

# %%
# Homo sapiens (human), species
taxid = '9606'
# cholesterol
chebi = 'CHEBI_16113'

sparql_Q9="""
#endpoint: https://sparql.uniprot.org/sparql/

PREFIX rdfs:<http://www.w3.org/2000/01/rdf-schema#>
PREFIX rh:<http://rdf.rhea-db.org/>
PREFIX ch:<http://purl.obolibrary.org/obo/> 
PREFIX up:<http://purl.uniprot.org/core/>
PREFIX taxon:<http://purl.uniprot.org/taxonomy/>
PREFIX genex: <http://purl.org/genex#>
PREFIX lscr: <http://purl.org/lscr#>

SELECT distinct ?protein 
                # ?ensemblGene 
                # ?reaction 
                # ?anatomicEntityLabel 
                # ?anatomicEntity
WHERE {
  # federated query to Rhea enadpoint
  {
    SELECT * WHERE {
      SERVICE <https://sparql.rhea-db.org/sparql> {
        # ?reaction rdfs:subClassOf rh:Reaction .
        # ?reaction rh:status rh:Approved .
        # ?reaction rh:equation ?reactionEquation .
        # ?reaction rh:side ?reactionSide .
        # ?reactionSide rh:contains ?participant .
        # ?participant rh:compound ?compound .
        # compound constraint
        # ?compound rh:chebi ch:""" + chebi + """ .
      }
    }
  }
  # taxonomy constraint
  # ?protein up:organism taxon:""" + taxid + """ .
  # ?protein up:annotation ?a .
  # ?a a up:Catalytic_Activity_Annotation .
  # ?a up:catalyticActivity ?ca .
  # ?ca up:catalyzedReaction ?reaction .
  # ?protein rdfs:seeAlso / up:transcribedFrom ?ensemblGene .
  
  # federated query to Bgee (expression data)
  SERVICE <http://biosoda.expasy.org/rdf4j-server/repositories/bgeelight> {
    # ?gene genex:isExpressedIn ?anatomicEntity .
    # ?gene lscr:xrefEnsemblGene ?ensemblGene .
    # ?anatomicEntity rdfs:label ?anatomicEntityLabel .
  }
}
"""
print(sparql_Q9)
# Out:
# #endpoint: https://sparql.uniprot.org/sparql/
#
# PREFIX rdfs:<http://www.w3.org/2000/01/rdf-schema#>
# PREFIX rh:<http://rdf.rhea-db.org/>
# PREFIX ch:<http://purl.obolibrary.org/obo/>
# PREFIX up:<http://purl.uniprot.org/core/>
# PREFIX taxon:<http://purl.uniprot.org/taxonomy/>
# PREFIX genex: <http://purl.org/genex#>
# PREFIX lscr: <http://purl.org/lscr#>
#
# SELECT distinct ?protein
#                 ?ensemblGene
#                 ?reaction
#                 ?anatomicEntityLabel
#                 ?anatomicEntity
# WHERE {
#   # federated query to Rhea enadpoint
#   {
#     SELECT * WHERE {
#       SERVICE <https://sparql.rhea-db.org/sparql> {
#         ?reaction rdfs:subClassOf rh:Reaction .
#         ?reaction rh:status rh:Approved .
#         ?reaction rh:equation ?reactionEquation .
#         ?reaction rh:side ?reactionSide .
#         ?reactionSide rh:contains ?participant .
#         ?participant rh:compound ?compound .
#         # compound constraint
# ...

# %%
try:
    df  = sparql2pandas(sparql_Q9,sparql_uniprot_url)
except Exception:
    print('ERROR in SPARQL query Q9')
    stop
    
# Display the 5 first rows
df.head(5)
# Out:
#                               anatomicEntity          anatomicEntityLabel  \
# 0  http://purl.obolibrary.org/obo/CL_0000015               male germ cell
# 1  http://purl.obolibrary.org/obo/CL_0000019                        sperm
# 2  http://purl.obolibrary.org/obo/CL_0000023                       oocyte
# 3  http://purl.obolibrary.org/obo/CL_0000083  epithelial cell of pancreas
# 4  http://purl.obolibrary.org/obo/CL_0000115             endothelial cell
#
#                                          ensemblGene  \
# 0  http://rdf.ebi.ac.uk/resource/ensembl/ENSG0000...
# 1  http://rdf.ebi.ac.uk/resource/ensembl/ENSG0000...
# 2  http://rdf.ebi.ac.uk/resource/ensembl/ENSG0000...
# 3  http://rdf.ebi.ac.uk/resource/ensembl/ENSG0000...
# 4  http://rdf.ebi.ac.uk/resource/ensembl/ENSG0000...
#
#                                   protein                      reaction
# 0  http://purl.uniprot.org/uniprot/O95477  http://rdf.rhea-db.org/39051
# ...

# %% [markdown]
# ## Q10: Build the UniProt H. pylori proteome scale metabolic network

# %%
# Helicobacter pylori str. 26695
taxid = '85962'

sparql_Q10="""
#endpoint: https://sparql.rhea-db.org/sparql
#query Q10: Build the UniProt H. pylori proteome scale metabolic network

PREFIX rdfs:<http://www.w3.org/2000/01/rdf-schema#>
PREFIX rh:<http://rdf.rhea-db.org/>
PREFIX up:<http://purl.uniprot.org/core/>
PREFIX taxon:<http://purl.uniprot.org/taxonomy/>
SELECT  ?protein 
        # ?proteinId
        # ?reaction 
        # ?reactionSide 
        # ?compound  
        # ?chebi 
        # ?reactionEquation
WHERE {
  SERVICE <http://sparql.uniprot.org/sparql> {
    # ?protein up:reviewed ?status .
    # taxonomy constraint
    # ?protein up:organism taxon:""" + taxid + """ .
    # ?protein up:mnemonic ?proteinId . 
    # Rhea reactions catalyzed by UniProt proteins
    # ?protein up:annotation ?a .
    # ?a up:catalyticActivity ?ca .
    # ?ca up:catalyzedReaction ?reaction .  
  }
  # ?reaction rh:equation ?reactionEquation .
  # ?reaction rh:side ?reactionSide .
  # ?reactionSide rh:contains ?participant .
  # ?participant rh:compound ?compound .
  OPTIONAL {?compound rh:chebi ?chebi } .
}
"""
print(sparql_Q10)
# Out:
# #endpoint: https://sparql.rhea-db.org/sparql
# #query Q10: Build the UniProt H. pylori proteome scale metabolic network
#
# PREFIX rdfs:<http://www.w3.org/2000/01/rdf-schema#>
# PREFIX rh:<http://rdf.rhea-db.org/>
# PREFIX up:<http://purl.uniprot.org/core/>
# PREFIX taxon:<http://purl.uniprot.org/taxonomy/>
# SELECT  ?protein
#         ?proteinId
#         ?reaction
#         ?reactionSide
#         ?compound
#         ?chebi
#         ?reactionEquation
# WHERE {
#   SERVICE <http://sparql.uniprot.org/sparql> {
#     ?protein up:reviewed ?status .
#     # taxonomy constraint
#     ?protein up:organism taxon:85962 .
#     ?protein up:mnemonic ?proteinId .
#     # Rhea reactions catalyzed by UniProt proteins
#     ?protein up:annotation ?a .
#     ?a up:catalyticActivity ?ca .
#     ?ca up:catalyzedReaction ?reaction .
#   }
#   ?reaction rh:equation ?reactionEquation .
#   ?reaction rh:side ?reactionSide .
#   ?reactionSide rh:contains ?participant .
# ...

# %%
try:
    df  = sparql2pandas(sparql_Q10,sparql_rhea_url)
except Exception:
    print('ERROR in SPARQL query Q10')
    stop
    
# Display the 5 first rows
df.head(5)
# Out:
#                                          chebi  \
# 0   http://purl.obolibrary.org/obo/CHEBI_26386
# 1  http://purl.obolibrary.org/obo/CHEBI_142361
# 2   http://purl.obolibrary.org/obo/CHEBI_83905
# 3   http://purl.obolibrary.org/obo/CHEBI_85987
# 4   http://purl.obolibrary.org/obo/CHEBI_85987
#
#                                 compound  \
# 0  http://rdf.rhea-db.org/Compound_14976
# 1  http://rdf.rhea-db.org/Compound_15011
# 2  http://rdf.rhea-db.org/Compound_10767
# 3  http://rdf.rhea-db.org/Compound_11525
# 4  http://rdf.rhea-db.org/Compound_11525
#
#                                   protein     proteinId  \
# 0  http://purl.uniprot.org/uniprot/P56463    DEOD_HELPY
# 1  http://purl.uniprot.org/uniprot/P56463    DEOD_HELPY
# 2  http://purl.uniprot.org/uniprot/O26027    MURE_HELPY
# 3  http://purl.uniprot.org/uniprot/O25016    KDSB_HELPY
# 4  http://purl.uniprot.org/uniprot/O25611  O25611_HELPY
#
#                        reaction  \
# 0  http://rdf.rhea-db.org/36431
# ...

# %% [markdown]
# ## Q11: Explore H. pylori tryptophan biosynthesis pathway (GO:0000162)

# %%
# Helicobacter pylori str. 26695 (UniProt proteome: HELPY)
taxid = '85962'
# tryptophan biosynthesis pathway (GO:0000162)
goid = 'GO:0000162'

sparql_Q11="""
#endpoint: https://sparql.uniprot.org/sparql/

PREFIX rdfs:<http://www.w3.org/2000/01/rdf-schema#> 
PREFIX up:<http://purl.uniprot.org/core/>
PREFIX rh:<http://rdf.rhea-db.org/>
PREFIX taxon:<http://purl.uniprot.org/taxonomy/>
PREFIX ch:<http://purl.obolibrary.org/obo/>
PREFIX GO:<http://purl.obolibrary.org/obo/GO_>
SELECT distinct ?upProteinId 
                # ?goId 
                # ?rhReaction 
                # ?upPathway 
WHERE{
  # ?upProtein up:reviewed true .
  # ?upProtein up:mnemonic  ?upProteinId . 
  # taxonomy constraint
  # ?upProtein up:organism taxon:""" + taxid + """ .
  # ?upProtein up:annotation/up:catalyticActivity/up:catalyzedReaction ?rhReaction .  
  # ?upProtein up:classifiedWith ?goId .
  # pathway constraint (GO Biological Process)
  VALUES ?goId {""" + goid + """} 
  OPTIONAL {?upProtein up:annotation ?pa . # Pathway annotation
                      # ?pa a up:Pathway_Annotation .  
                      # ?pa rdfs:seeAlso/rdfs:label ?upPathway . }
}
ORDER BY ?upPathway 
"""
print(sparql_Q11)
# Out:
# #endpoint: https://sparql.uniprot.org/sparql/
#
# PREFIX rdfs:<http://www.w3.org/2000/01/rdf-schema#>
# PREFIX up:<http://purl.uniprot.org/core/>
# PREFIX rh:<http://rdf.rhea-db.org/>
# PREFIX taxon:<http://purl.uniprot.org/taxonomy/>
# PREFIX ch:<http://purl.obolibrary.org/obo/>
# PREFIX GO:<http://purl.obolibrary.org/obo/GO_>
# SELECT distinct ?upProteinId
#                 ?goId
#                 ?rhReaction
#                 ?upPathway
# WHERE{
#   ?upProtein up:reviewed true .
#   ?upProtein up:mnemonic  ?upProteinId .
#   # taxonomy constraint
#   ?upProtein up:organism taxon:85962 .
#   ?upProtein up:annotation/up:catalyticActivity/up:catalyzedReaction ?rhReaction .
#   ?upProtein up:classifiedWith ?goId .
#   # pathway constraint (GO Biological Process)
#   VALUES ?goId {GO:0000162}
#   OPTIONAL {?upProtein up:annotation ?pa . # Pathway annotation
#                       ?pa a up:Pathway_Annotation .
#                       ?pa rdfs:seeAlso/rdfs:label ?upPathway . }
# }
# ...

# %%
try:
    df  = sparql2pandas(sparql_Q11,sparql_uniprot_url)
except Exception:
    print('ERROR in SPARQL query Q11')
    
# Display all results
df
# Out:
#                                         goId                    rhReaction  \
# 0  http://purl.obolibrary.org/obo/GO_0000162  http://rdf.rhea-db.org/11768
# 1  http://purl.obolibrary.org/obo/GO_0000162  http://rdf.rhea-db.org/10532
# 2  http://purl.obolibrary.org/obo/GO_0000162  http://rdf.rhea-db.org/10532
# 3  http://purl.obolibrary.org/obo/GO_0000162  http://rdf.rhea-db.org/23476
# 4  http://purl.obolibrary.org/obo/GO_0000162  http://rdf.rhea-db.org/21540
# 5  http://purl.obolibrary.org/obo/GO_0000162  http://rdf.rhea-db.org/21540
# 6  http://purl.obolibrary.org/obo/GO_0000162  http://rdf.rhea-db.org/23476
# 7  http://purl.obolibrary.org/obo/GO_0000162  http://rdf.rhea-db.org/21732
# 8  http://purl.obolibrary.org/obo/GO_0000162  http://rdf.rhea-db.org/21732
#
#                                            upPathway upProteinId
# 0  Amino-acid biosynthesis; L-tryptophan biosynth...  TRPD_HELPY
# 1  Amino-acid biosynthesis; L-tryptophan biosynth...  TRPB_HELPY
# ...

# %% [markdown]
# ## Q12: H. pylori enzyme complexes for tryptophan biosynthesis pathway (MetaNetX: seed_Opt85962_1)

# %%
sparql_Q12="""
#endpoint: https://sparql.uniprot.org/sparql/
#query Q12: H. pylori enzyme complexes for tryptophan biosynthesis pathway (MetaNetX: seed_Opt85962_1)

PREFIX rdfs:<http://www.w3.org/2000/01/rdf-schema#>
PREFIX up:<http://purl.uniprot.org/core/>
PREFIX rh:<http://rdf.rhea-db.org/>
PREFIX taxon:<http://purl.uniprot.org/taxonomy/>
PREFIX mnx:<https://rdf.metanetx.org/schema/>
PREFIX mnet:<https://rdf.metanetx.org/mnet/>
PREFIX GO:<http://purl.obolibrary.org/obo/GO_>

SELECT distinct
    # ?upPathway
    # ?upProteinId
    # ?rhReaction
    # ?mnxr
    # ?cplx_label
    # ?mnet
WHERE{
    # ?upProtein up:reviewed true .
    # ?upProtein up:mnemonic ?upProteinId .
    # taxonomy constraint
    # ?upProtein up:organism taxon:""" + taxid + """ .
    # pathway constraint (GO Biological Process)
    # ?upProtein up:classifiedWith {""" + goid + """} .
    # ?upProtein up:annotation/up:catalyticActivity/up:catalyzedReaction ?rhReaction .
    # Pathway annotation
    OPTIONAL {?upProtein up:annotation ?pa           . 
              # ?pa a up:Pathway_Annotation            ;  
                  rdfs:seeAlso/rdfs:label ?upPathway . }
    SERVICE <https://rdf.metanetx.org/sparql> {
        # ?mnxr mnx:reacXref ?rhReaction .
        # ?reac mnx:mnxr     ?mnxr       .
        # ?gpr  mnx:reac     ?reac       ;
              mnx:cata     ?cata       .
        # ?cata mnx:cplx     ?cplx       .
        # ?cplx rdfs:label   ?cplx_label .
        # ?mnet mnx:gpr      ?gpr        .
        VALUES ?mnet {mnet:seed_Opt85962_1}
    }
}
ORDER BY ?upPathway
"""
print(sparql_Q12)
# Out:
# #endpoint: https://sparql.uniprot.org/sparql/
# #query Q12: H. pylori enzyme complexes for tryptophan biosynthesis pathway (MetaNetX: seed_Opt85962_1)
#
# PREFIX rdfs:<http://www.w3.org/2000/01/rdf-schema#>
# PREFIX up:<http://purl.uniprot.org/core/>
# PREFIX rh:<http://rdf.rhea-db.org/>
# PREFIX taxon:<http://purl.uniprot.org/taxonomy/>
# PREFIX mnx:<https://rdf.metanetx.org/schema/>
# PREFIX mnet:<https://rdf.metanetx.org/mnet/>
# PREFIX GO:<http://purl.obolibrary.org/obo/GO_>
#
# SELECT distinct
#     ?upPathway
#     ?upProteinId
#     ?rhReaction
#     ?mnxr
#     ?cplx_label
#     ?mnet
# WHERE{
#     ?upProtein up:reviewed true .
#     ?upProtein up:mnemonic ?upProteinId .
#     # taxonomy constraint
#     ?upProtein up:organism taxon:85962 .
#     # pathway constraint (GO Biological Process)
#     ?upProtein up:classifiedWith {GO:0000162} .
#     ?upProtein up:annotation/up:catalyticActivity/up:catalyzedReaction ?rhReaction .
#     # Pathway annotation
# ...

# %%
try:
    df  = sparql2pandas(sparql_Q12,sparql_uniprot_url)
except Exception:
    print('ERROR in SPARQL query Q12')
    
# Display all results
df
# Out:
# ERROR in SPARQL query Q12
#                                         goId                    rhReaction  \
# 0  http://purl.obolibrary.org/obo/GO_0000162  http://rdf.rhea-db.org/11768
# 1  http://purl.obolibrary.org/obo/GO_0000162  http://rdf.rhea-db.org/10532
# 2  http://purl.obolibrary.org/obo/GO_0000162  http://rdf.rhea-db.org/10532
# 3  http://purl.obolibrary.org/obo/GO_0000162  http://rdf.rhea-db.org/23476
# 4  http://purl.obolibrary.org/obo/GO_0000162  http://rdf.rhea-db.org/21540
# 5  http://purl.obolibrary.org/obo/GO_0000162  http://rdf.rhea-db.org/21540
# 6  http://purl.obolibrary.org/obo/GO_0000162  http://rdf.rhea-db.org/23476
# 7  http://purl.obolibrary.org/obo/GO_0000162  http://rdf.rhea-db.org/21732
# 8  http://purl.obolibrary.org/obo/GO_0000162  http://rdf.rhea-db.org/21732
#
#                                            upPathway upProteinId
# 0  Amino-acid biosynthesis; L-tryptophan biosynth...  TRPD_HELPY
# ...

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Venn diagram showing the taxonomic distribution of Rhea reactions annotated in UniProtKB/Swiss-Prot (UniProtKB/Swiss-Prot)
#
# |Taxonomic domain name | NCBI taxid |
# |----------------------|------------|
# | Archaea | 2157 |
# | Bacteria | 2 |
# | Eukaryota | 2759 |
# | Viruses | 10239 |
#
#
# WARNING: the SPARQL query may take a few minutes

# %% [markdown]
# ### Q20: Retrieve UniProtKB/Swiss-Prot proteins, their taxonomic domain and their catalyzed Rhea reactions

# %%
sparql_Q20="""
#endpoint: https://sparql.uniprot.org/sparql/
#query Q20: Retrieve UniProtKB/Swiss-Prot proteins, their taxonomic domain and their catalyzed Rhea reactions

PREFIX rdfs:<http://www.w3.org/2000/01/rdf-schema#> 
PREFIX up:<http://purl.uniprot.org/core/>
PREFIX keywords:<http://purl.uniprot.org/keywords/>
PREFIX taxon:<http://purl.uniprot.org/taxonomy/>

SELECT distinct ?upProtein  
                # ?taxid
                # ?domain
                # ?domainName
                # ?rhReaction
WHERE {
  # UniProtKB/Swiss-Prot entries (reviewed)
  # ?upProtein up:reviewed true .
  # 
  # ?upProtein up:organism ?taxid .
  # ?taxid rdfs:subClassOf ?domain .
  VALUES (?domain) { (taxon:2157) (taxon:2) (taxon:2759) (taxon:10239)} 
  # ?domain up:scientificName ?domainName .
  # ?upProtein up:annotation/up:catalyticActivity/up:catalyzedReaction ?rhReaction .
}
"""
    
print(sparql_Q20)
# Out:
# #endpoint: https://sparql.uniprot.org/sparql/
# #query Q20: Retrieve UniProtKB/Swiss-Prot proteins, their taxonomic domain and their catalyzed Rhea reactions
#
# PREFIX rdfs:<http://www.w3.org/2000/01/rdf-schema#>
# PREFIX up:<http://purl.uniprot.org/core/>
# PREFIX keywords:<http://purl.uniprot.org/keywords/>
# PREFIX taxon:<http://purl.uniprot.org/taxonomy/>
#
# SELECT distinct ?upProtein
#                 ?taxid
#                 ?domain
#                 ?domainName
#                 ?rhReaction
# WHERE {
#   # UniProtKB/Swiss-Prot entries (reviewed)
#   ?upProtein up:reviewed true .
#   #
#   ?upProtein up:organism ?taxid .
#   ?taxid rdfs:subClassOf ?domain .
#   VALUES (?domain) { (taxon:2157) (taxon:2) (taxon:2759) (taxon:10239)}
#   ?domain up:scientificName ?domainName .
#   ?upProtein up:annotation/up:catalyticActivity/up:catalyzedReaction ?rhReaction .
# }

# %%
try:
    df_up_rh  = sparql2pandas(sparql_Q20,sparql_uniprot_url)
except Exception:
    print('ERROR in SPARQL query Q20')
    
# Display all results
df_up_rh.head(5)
# Out:
#                                   domain domainName  \
# 0     http://purl.uniprot.org/taxonomy/2   Bacteria
# 1  http://purl.uniprot.org/taxonomy/2157    Archaea
# 2  http://purl.uniprot.org/taxonomy/2157    Archaea
# 3  http://purl.uniprot.org/taxonomy/2157    Archaea
# 4  http://purl.uniprot.org/taxonomy/2157    Archaea
#
#                      rhReaction                                    taxid  \
# 0  http://rdf.rhea-db.org/21708   http://purl.uniprot.org/taxonomy/29448
# 1  http://rdf.rhea-db.org/24836  http://purl.uniprot.org/taxonomy/188937
# 2  http://rdf.rhea-db.org/55204  http://purl.uniprot.org/taxonomy/187420
# 3  http://rdf.rhea-db.org/42408  http://purl.uniprot.org/taxonomy/186497
# 4  http://rdf.rhea-db.org/23404  http://purl.uniprot.org/taxonomy/186497
#
#                                     upProtein
# 0  http://purl.uniprot.org/uniprot/A0A087WNH6
# 1      http://purl.uniprot.org/uniprot/Q8TU67
# 2      http://purl.uniprot.org/uniprot/O27266
# ...

# %% [markdown]
# ### Compute Venn diagram using matplotlib and matplotlib_venn python libraries

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3
from matplotlib_venn import venn3_circles

set_A = set(df_up_rh[df_up_rh.domainName == 'Archaea']['rhReaction'].drop_duplicates())
set_B = set(df_up_rh[df_up_rh.domainName == 'Bacteria']['rhReaction'].drop_duplicates())
set_E = set(df_up_rh[df_up_rh.domainName == 'Eukaryota']['rhReaction'].drop_duplicates())

nb_A = len(set_A)
nb_B = len(set_B)
nb_E = len(set_E)
nb_all = len(set_A | set_B | set_E)

title = 'Taxonomic distribution of the Rhea reactions annotated in UniProtKB/Swiss-Prot\n'
title += 'Rhea reactions: in Archaea=%s ; in Bacteria=%s; in Eukaryota=%s\n' % (nb_A, nb_B, nb_E)

# Plot Venn diagram
v=venn3([set_B,set_E,set_A], set_labels = ('Bacteria','Eukaryota', '\nArchaea'))
c=venn3_circles([set_B,set_E,set_A], linestyle='dashed', linewidth=1, color="grey")
plt.title(title)

plt.show();

# %% [markdown]
# # IDSM/Sachem service

# %% [markdown]
# ## Q30: Retrieve the Rhea reactions that involve cholesterol or cholesterol derivatives
#
# Perfom a chemical substructure search using IDSM/Sachem service.
# Input: SMILES

# %%
smiles = "C1[C@@]2([C@]3(CC[C@]4([C@]([C@@]3(CC=C2C[C@H](C1)O)[H])(CC[C@@]4([C@H](C)CCCC(C)C)[H])[H])C)[H])C"

sparql_Q30='''
#endpoint:https://sparql.rhea-db.org/sparql

PREFIX rdfs:<http://www.w3.org/2000/01/rdf-schema#>
PREFIX sachem:<http://bioinfo.uochb.cas.cz/rdf/v1.0/sachem#>
PREFIX idsm:<https://idsm.elixir-czech.cz/sparql/endpoint/>
PREFIX up:<http://purl.uniprot.org/core/>
PREFIX rh:<http://rdf.rhea-db.org/>

SELECT DISTINCT ?chebi 
                # ?chebiUniprotName 
                # ?rhReaction 
                # ?rhReactionEquation 
WHERE {
  SERVICE idsm:chebi {
    # ?chebi sachem:substructureSearch
    [ sachem:query "''' + smiles + '''" ] .
  }
  # ?rhReaction rdfs:subClassOf rh:Reaction .
  # ?rhReaction rh:equation ?rhReactionEquation .
  # ?rhReaction rh:status ?status .
  VALUES (?status) {(rh:Approved) (rh:Preliminary)}
  # ?rhReaction rh:side ?reactionSide .
  # ?reactionSide rh:contains ?participant .
  # ?participant rh:compound ?compound .
  # ?compound rh:chebi ?chebi .
  # ?chebi up:name ?chebiUniprotName .
}
'''

print(sparql_Q30)
# Out:
# #endpoint:https://sparql.rhea-db.org/sparql
#
# PREFIX rdfs:<http://www.w3.org/2000/01/rdf-schema#>
# PREFIX sachem:<http://bioinfo.uochb.cas.cz/rdf/v1.0/sachem#>
# PREFIX idsm:<https://idsm.elixir-czech.cz/sparql/endpoint/>
# PREFIX up:<http://purl.uniprot.org/core/>
# PREFIX rh:<http://rdf.rhea-db.org/>
#
# SELECT DISTINCT ?chebi
#                 ?chebiUniprotName
#                 ?rhReaction
#                 ?rhReactionEquation
# WHERE {
#   SERVICE idsm:chebi {
#     ?chebi sachem:substructureSearch
#     [ sachem:query "C1[C@@]2([C@]3(CC[C@]4([C@]([C@@]3(CC=C2C[C@H](C1)O)[H])(CC[C@@]4([C@H](C)CCCC(C)C)[H])[H])C)[H])C" ] .
#   }
#   ?rhReaction rdfs:subClassOf rh:Reaction .
#   ?rhReaction rh:equation ?rhReactionEquation .
#   ?rhReaction rh:status ?status .
#   VALUES (?status) {(rh:Approved) (rh:Preliminary)}
#   ?rhReaction rh:side ?reactionSide .
#   ?reactionSide rh:contains ?participant .
#   ?participant rh:compound ?compound .
#   ?compound rh:chebi ?chebi .
# ...

# %%
try:
    df  = sparql2pandas(sparql_Q30,sparql_rhea_url)
except Exception:
    print('ERROR in SPARQL query 30')
    stop
    
# Display the 5 first rows
df.head(5)
# Out:
#                                         chebi  \
# 0  http://purl.obolibrary.org/obo/CHEBI_15574
# 1  http://purl.obolibrary.org/obo/CHEBI_15575
# 2  http://purl.obolibrary.org/obo/CHEBI_15577
# 3  http://purl.obolibrary.org/obo/CHEBI_17500
# 4  http://purl.obolibrary.org/obo/CHEBI_17500
#
#                       chebiUniprotName                    rhReaction  \
# 0                           nuatigenin  http://rdf.rhea-db.org/19329
# 1  nuatigenin 3-beta-D-glucopyranoside  http://rdf.rhea-db.org/19329
# 2      (24R,24(1)R)-fucosterol epoxide  http://rdf.rhea-db.org/10884
# 3            7alpha-hydroxycholesterol  http://rdf.rhea-db.org/21812
# 4            7alpha-hydroxycholesterol  http://rdf.rhea-db.org/46380
#
#                                   rhReactionEquation
# 0  nuatigenin + UDP-alpha-D-glucose = H(+) + nuat...
# 1  nuatigenin + UDP-alpha-D-glucose = H(+) + nuat...
# 2  (24R,24(1)R)-fucosterol epoxide = acetaldehyde...
# 3  cholesterol + O2 + reduced [NADPH--hemoprotein...
# ...
